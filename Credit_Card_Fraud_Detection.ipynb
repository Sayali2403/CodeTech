# %% [markdown]
# Importing the dependencies

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
#Loading dataset to Pandas Dataframe
credit_card_data = pd.read_csv('/content/creditcard.csv')

# %%
#first 5 rows of the dataset
credit_card_data.head()
# Out:
#    Time        V1        V2        V3        V4  ...       V26       V27       V28  Amount  Class
# 0     0 -1.359807 -0.072781  2.536347  1.378155  ... -0.189115  0.133558 -0.021053  149.62    0.0
# 1     0  1.191857  0.266151  0.166480  0.448154  ...  0.125895 -0.008983  0.014724    2.69    0.0
# 2     1 -1.358354 -1.340163  1.773209  0.379780  ... -0.139097 -0.055353 -0.059752  378.66    0.0
# 3     1 -0.966272 -0.185226  1.792993 -0.863291  ... -0.221929  0.062723  0.061458  123.50    0.0
# 4     2 -1.158233  0.877737  1.548718  0.403034  ...  0.502292  0.219422  0.215153   69.99    0.0
#
# [5 rows x 31 columns]

# %%
credit_card_data.tail()
# Out:
#         Time        V1        V2        V3        V4  ...       V26       V27       V28  Amount  Class
# 29794  35633  0.786689 -0.691214 -0.329291  0.149435  ...  0.332321 -0.001435  0.025559  200.00    0.0
# 29795  35633  0.800996 -2.159993  0.008378 -1.081828  ... -0.212022 -0.024151  0.077021  363.00    0.0
# 29796  35633  1.115726 -0.472602  0.983034  0.294673  ...  1.121835 -0.060566  0.003541   36.92    0.0
# 29797  35634  1.239103 -1.000617  0.843324 -0.560021  ... -0.023495  0.036574  0.035202   91.00    0.0
# 29798  35634  1.374193 -0.720679  0.891375 -0.541402  ...       NaN       NaN       NaN     NaN    NaN
#
# [5 rows x 31 columns]

# %%
#number of rows and columns
credit_card_data.shape
# Out:
# (29799, 31)

# %%
#dataset information
credit_card_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29799 entries, 0 to 29798
# Data columns (total 31 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Time    29799 non-null  int64
#  1   V1      29799 non-null  float64
#  2   V2      29799 non-null  float64
#  3   V3      29799 non-null  float64
#  4   V4      29799 non-null  float64
#  5   V5      29799 non-null  float64
#  6   V6      29799 non-null  float64
#  7   V7      29799 non-null  float64
#  8   V8      29799 non-null  float64
#  9   V9      29799 non-null  float64
#  10  V10     29799 non-null  float64
#  11  V11     29799 non-null  float64
#  12  V12     29799 non-null  float64
#  13  V13     29799 non-null  float64
#  14  V14     29799 non-null  float64
#  15  V15     29799 non-null  float64
#  16  V16     29799 non-null  float64
#  17  V17     29799 non-null  float64
#  18  V18     29799 non-null  float64
#  19  V19     29799 non-null  float64
#  20  V20     29799 non-null  float64
#  21  V21     29799 non-null  float64
#  22  V22     29799 non-null  float64
#  23  V23     29799 non-null  float64
#  24  V24     29799 non-null  float64
#  25  V25     29799 non-null  float64
#  26  V26     29799 non-null  float64
#  27  V27     29799 non-null  float64
#  28  V28     29799 non-null  float64
#  29  Amount  29799 non-null  float64
#  30  Class   29799 non-null  float64
# dtypes: float64(30), int64(1)
# memory usage: 7.0 MB

# %%
#check missing values in dataset
credit_card_data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        1
# V7        1
# V8        1
# V9        1
# V10       1
# V11       1
# V12       1
# V13       1
# V14       1
# V15       1
# V16       1
# V17       1
# V18       1
# V19       1
# V20       1
# V21       1
# V22       1
# V23       1
# V24       1
# V25       1
# V26       1
# V27       1
# V28       1
# Amount    1
# Class     1
# dtype: int64

# %%
credit_card_data_cleaned = credit_card_data.dropna()

# %%
print (credit_card_data_cleaned)
# Out:
#         Time        V1        V2        V3        V4  ...       V26       V27       V28  Amount  Class
# 0          0 -1.359807 -0.072781  2.536347  1.378155  ... -0.189115  0.133558 -0.021053  149.62    0.0
# 1          0  1.191857  0.266151  0.166480  0.448154  ...  0.125895 -0.008983  0.014724    2.69    0.0
# 2          1 -1.358354 -1.340163  1.773209  0.379780  ... -0.139097 -0.055353 -0.059752  378.66    0.0
# 3          1 -0.966272 -0.185226  1.792993 -0.863291  ... -0.221929  0.062723  0.061458  123.50    0.0
# 4          2 -1.158233  0.877737  1.548718  0.403034  ...  0.502292  0.219422  0.215153   69.99    0.0
# ...      ...       ...       ...       ...       ...  ...       ...       ...       ...     ...    ...
# 35736  38239 -3.120568 -0.121316  1.307875  1.582101  ... -0.070668 -0.870421  0.624730    2.28    0.0
# 35737  38240  1.232390  0.122010  0.157352  0.261906  ...  0.158446 -0.018118 -0.003168    1.79    0.0
# 35738  38240  1.114040  0.571203  0.427035  2.442135  ... -0.025773 -0.035775  0.011219   24.99    0.0
# 35739  38241  1.057020  0.007895  0.239256  1.236048  ... -0.314989  0.027467  0.010613   53.96    0.0
# 35740  38241 -1.546226  0.693338  1.002815 -1.528992  ...  0.739989  0.043625 -0.140629    0.76    0.0
#
# [35741 rows x 31 columns]

# %%
#distribution of legit transaction and fradulent transaction
credit_card_data['Class'].value_counts()
# Out:
# Class
# 0.0    35638
# 1.0      103
# Name: count, dtype: int64

# %% [markdown]
# This Dataset is highly unbalanced

# %% [markdown]
# 0 = Normal Transaction

# %% [markdown]
# 1 = Fradulent Transaction

# %%
#seperating data for analysis
legit = credit_card_data[credit_card_data.Class == 0]
fraud = credit_card_data[credit_card_data.Class == 1]

# %%
print(legit.shape)
print(fraud.shape)
# Out:
# (35638, 31)
# (103, 31)

# %%
#statistical measures of the data
legit.Amount.describe()
# Out:
# count    35638.000000
# mean        84.185241
# std        227.223359
# min          0.000000
# 25%          7.000000
# 50%         22.000000
# 75%         76.000000
# max       7879.420000
# Name: Amount, dtype: float64

# %%
fraud.Amount.describe()
# Out:
# count     103.000000
# mean       90.471165
# std       247.173335
# min         0.000000
# 25%         1.000000
# 50%         3.760000
# 75%        99.990000
# max      1809.680000
# Name: Amount, dtype: float64

# %%
#compare the values for both transactions
credit_card_data.groupby('Class').mean()
# Out:
#                Time        V1        V2         V3  ...       V26       V27       V28     Amount
# Class                                               ...
# 0.0    24007.013890 -0.186593  0.055909   0.752026  ...  0.021354  0.008491  0.003549  84.185241
# 1.0    20498.291262 -7.762676  5.838647 -10.957218  ...  0.180390  0.822304  0.102481  90.471165
#
# [2 rows x 30 columns]

# %% [markdown]
# Under Sampling

# %% [markdown]
# Build sample datset containing similar distribution of normal and fradulent transaction

# %%
legit_sample = legit.sample(n=103)

# %% [markdown]
# Concatenation two dataframes

# %%
new_dataset = pd.concat([legit_sample,fraud],axis=0)

# %%
new_dataset.head()
# Out:
#         Time        V1        V2        V3        V4  ...       V26       V27       V28  Amount  Class
# 19656  30442  0.960089 -0.833866  0.849283  0.633604  ... -0.344320  0.036178  0.055045  158.00    0.0
# 33533  37268  1.149505  0.396102  0.615531  2.310495  ... -0.257171 -0.024791  0.012328   10.51    0.0
# 5015    4596  1.116750 -0.470737  0.228822 -1.806058  ... -0.768814  0.117068  0.001664    2.18    0.0
# 7505   10247  1.062773 -0.093531  1.485816  1.439849  ... -0.442725  0.050931  0.016670    4.99    0.0
# 7480   10180 -0.467669  1.075407  1.725491  0.062699  ...  0.015819  0.232992  0.104472    2.67    0.0
#
# [5 rows x 31 columns]

# %%
new_dataset.tail()
# Out:
#         Time        V1        V2        V3        V4  ...       V26       V27       V28  Amount  Class
# 30442  35926 -3.896583  4.518355 -4.454027  5.547453  ...  0.412191  0.635789  0.501050    4.56    1.0
# 30473  35942 -4.194074  4.382897 -5.118363  4.455230  ... -0.131687  0.473934  0.473757   14.46    1.0
# 30496  35953 -4.844372  5.649439 -6.730396  5.252842  ... -0.270328  0.210214  0.391855  111.70    1.0
# 31002  36170 -5.685013  5.776516 -7.064977  5.902715  ... -0.049447  0.303445  0.219380  111.70    1.0
# 33276  37167 -7.923891 -5.198360 -3.000024  4.420666  ...  0.520508  1.937421 -1.552593   12.31    1.0
#
# [5 rows x 31 columns]

# %%
new_dataset['Class'].value_counts()
# Out:
# Class
# 0.0    103
# 1.0    103
# Name: count, dtype: int64

# %%
new_dataset.groupby('Class').mean()
# Out:
#                Time        V1        V2         V3  ...       V26       V27       V28     Amount
# Class                                               ...
# 0.0    21641.097087  0.117184  0.202749   0.905756  ...  0.018912 -0.020658 -0.004467  50.933495
# 1.0    20498.291262 -7.762676  5.838647 -10.957218  ...  0.180390  0.822304  0.102481  90.471165
#
# [2 rows x 30 columns]

# %% [markdown]
# Spliting the data in features and targets

# %%
X = new_dataset.drop(columns='Class',axis=1)
Y = new_dataset['Class']

# %%
print(X)
# Out:
#         Time        V1        V2        V3  ...       V26       V27       V28  Amount
# 19656  30442  0.960089 -0.833866  0.849283  ... -0.344320  0.036178  0.055045  158.00
# 33533  37268  1.149505  0.396102  0.615531  ... -0.257171 -0.024791  0.012328   10.51
# 5015    4596  1.116750 -0.470737  0.228822  ... -0.768814  0.117068  0.001664    2.18
# 7505   10247  1.062773 -0.093531  1.485816  ... -0.442725  0.050931  0.016670    4.99
# 7480   10180 -0.467669  1.075407  1.725491  ...  0.015819  0.232992  0.104472    2.67
# ...      ...       ...       ...       ...  ...       ...       ...       ...     ...
# 30442  35926 -3.896583  4.518355 -4.454027  ...  0.412191  0.635789  0.501050    4.56
# 30473  35942 -4.194074  4.382897 -5.118363  ... -0.131687  0.473934  0.473757   14.46
# 30496  35953 -4.844372  5.649439 -6.730396  ... -0.270328  0.210214  0.391855  111.70
# 31002  36170 -5.685013  5.776516 -7.064977  ... -0.049447  0.303445  0.219380  111.70
# 33276  37167 -7.923891 -5.198360 -3.000024  ...  0.520508  1.937421 -1.552593   12.31
#
# [206 rows x 30 columns]

# %%
print(Y)
# Out:
# 19656    0.0
# 33533    0.0
# 5015     0.0
# 7505     0.0
# 7480     0.0
#         ...
# 30442    1.0
# 30473    1.0
# 30496    1.0
# 31002    1.0
# 33276    1.0
# Name: Class, Length: 206, dtype: float64

# %% [markdown]
# split data in training and test data

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.3,stratify=Y,random_state=3)

# %%
print(X.shape,X_train.shape,X_test.shape)
# Out:
# (206, 30) (144, 30) (62, 30)

# %% [markdown]
# Model Training

# %% [markdown]
# Logistic Regression

# %%
model = LogisticRegression()

# %%
#training logistic regression model with training data
model.fit(X_train,Y_train)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %% [markdown]
# Model Evaluation

# %% [markdown]
# Accuracy Score

# %%
#accuracy on training data
X_train_prediction = model.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction,Y_train)

# %%
print('Accuracy on training data : ',training_data_accuracy)
# Out:
# Accuracy on training data :  0.9722222222222222

# %%
#accuracy on test data
X_test_prediction = model.predict(X_test)
test_data_accuracy = accuracy_score(X_test_prediction,Y_test)

# %%
print('Accuracy on test data : ',test_data_accuracy)
# Out:
# Accuracy on test data :  0.9838709677419355
